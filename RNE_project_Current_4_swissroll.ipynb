# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import SpectralClustering, KMeans
import tkinter
import numpy.matlib
np.set_printoptions(suppress=True)
from numpy import linalg as LA
import scipy.sparse as sp
import pywt
import tensorflow as tf
import tensorflow_probability as tfp
import pywt
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
from sklearn.manifold import LocallyLinearEmbedding, SpectralEmbedding
from sklearn import mixture
from sklearn.preprocessing import StandardScaler

# %%
data = np.loadtxt("swissroll.txt")
data_2d = np.loadtxt("preswissroll.txt")
label = np.loadtxt("preswissroll_labels.txt")

# %%
data
# Out:
# array([[ -5.214647  ,   7.0879738 ,   6.7292474 ],
#        [ -0.42176168,   8.4266375 ,   7.896089  ],
#        [ -6.1346009 ,   5.6864362 ,   6.0885666 ],
#        ...,
#        [ 12.440832  ,  12.176057  ,  -1.0322797 ],
#        [  9.6128784 ,  11.898241  ,  -7.0691012 ],
#        [ -0.94566403,  11.501216  , -10.867711  ]])

# %%
label
# Out:
# array([1., 1., 1., ..., 4., 4., 4.])

# %% [markdown]
# # original RNE

# %%
def find_neighbors(X, n_neighbors=6):
    """
    Compute the square distance matrix using Euclidean distance
    :param X: Input data, a numpy array of shape (n, d)
    :param n_neighbors: Number of nearest neighbors to consider, int
    :return: numpy array of shape (n, n_neighbors), numpy array of shape (n, n_neighbors)
    """
    def dist(a, b):
        return np.sqrt(sum((a - b)**2))

    # Compute full distance matrix (n , n)
    distances = np.array([[dist(p1, p2) for p2 in X] for p1 in X])

    # by default, Keep only the 6 nearest neighbors, others set to 0 (= unreachable)
    neighbor_idx = np.argsort(distances, axis=1)[:, 1:n_neighbors+1]

    return neighbor_idx


def weight_LLE(data, n_neighbors=6):
    n = data.shape[0]
    # Compute the nearest neighbors
    print("finding ",n_neighbors," neighbors for ",n," data")
    neighbors_idx = find_neighbors(data, n_neighbors)

    w = np.zeros((n, n))

    #print("calculating weights")
    for i in range(n):
        # Center the neighbors matrix
        k_indexes = neighbors_idx[i, :]
        neighbors = data[k_indexes, :] - data[i, :]

        # Compute the corresponding gram matrix
        gram_inv = np.linalg.pinv(np.dot(neighbors, neighbors.T))

        # Setting the weight values according to the lagrangian
        lambda_par = 2/np.sum(gram_inv)
        w[i, k_indexes] = lambda_par*np.sum(gram_inv, axis=1)/2

        #if i%(np.int(n/10)) == 0:
        #    print(i/np.int(n/10)*10,"%")

    return w

# %%
def robust_neighbor_embedding(X, n_neighbors, out_dim, tol=1e-6, max_iter=200):
    
    # LLE's weight matrix
    W = weight_LLE(X,n_neighbors)
    

    n,d = X.shape
    H = np.random.rand(d,out_dim).round(4)
    ## W
    
    # M = (I-W)' (I-W)
    #A = eye(*W.shape, format=W.format) - W
    #A = (A.T).dot(A).tocsr()
    A = np.dot((np.eye(n) - np.transpose(W)), X)    
    AA = np.dot(A.T,A) #.tocsr()
    AAplus = 0.5 * (np.abs(AA) + AA)
    AAsubtract = 0.5 * (np.abs(AA) - AA)
    
    #initialize H, Y, alpha, gamma, gamma_max, mu
    M = np.dot(A, H)
    Y = np.zeros((n,out_dim))
    mu = 1.1
    gamma = 10
    max_gamma = 10000000000.0
    alpha = 1000.0
    iter_num = 100
    iter_numH = 100

    eps = 0.0001

    for j in np.arange(1, iter_num+1):
        AM = np.dot(np.transpose(A), M)
        AY = np.dot(np.transpose(A), Y)
        AMplus = 0.5 * (np.abs(AM) + AM)
        AMsubtract = 0.5 * (np.abs(AM) - AM)
        AYplus = 0.5 * (np.abs(AY) + AY)
        AYsubtract = 0.5 * (np.abs(AY) - AY)

        #update H
        for i in np.arange(1, iter_numH+1):

            G1 = np.diag(np.sqrt(1.0 / np.diag(np.dot(np.transpose(H), H)) + eps)).round(4)
            #print("G1", G1)
            H = np.dot(H, G1)
            a = (np.dot((alpha * H ), np.dot(np.transpose(H), H))+gamma * AMsubtract + gamma * np.dot(AAplus,H)+ AYsubtract + eps)
            c = ((alpha * H) + (gamma * AMplus) + np.dot(gamma*AAsubtract, H) + AYplus)
            H = H * np.sqrt(c/a)        
        
        # Update M
        temp = np.dot(A,H)-Y/gamma
        M = pywt.threshold(temp,1/gamma, mode='soft')

        # Update Y
        Y = Y + gamma*(M-np.dot(A,H)).round(4)
        
        # Update gamma
        gamma = min(mu*gamma,max_gamma)

    index_amplitude = np.sum(H*H,axis=1) #contribution of each feature 1~d
    ranking = np.argsort(-index_amplitude) #biggest first
    selected_index = ranking[0:out_dim] #select 1~out_dim
    print(selected_index)

    X_rne = X[:,selected_index]


    return X_rne

#, H

# %%
robust_neighbor_embedding(data, 12, 2, tol=1e-6, max_iter=200)
# Out:
# finding  12  neighbors for  1600  data
# [1 0]
# array([[ 7.0879738 , -5.214647  ],
#        [ 8.4266375 , -0.42176168],
#        [ 5.6864362 , -6.1346009 ],
#        ...,
#        [12.176057  , 12.440832  ],
#        [11.898241  ,  9.6128784 ],
#        [11.501216  , -0.94566403]])

# %%
robust_neighbor_embedding_modified(data, 12, 2, tol=1e-6, max_iter=200)
# Out:
# [1 2]
# array([[  7.0879738,   6.7292474],
#        [  8.4266375,   7.896089 ],
#        [  5.6864362,   6.0885666],
#        ...,
#        [ 12.176057 ,  -1.0322797],
#        [ 11.898241 ,  -7.0691012],
#        [ 11.501216 , -10.867711 ]])

# %%
robust_neighbor_embedding_modified_2(data, 12, 2, tol=1e-6, max_iter=200)
# Out:
# finding  45  neighbors for  1600  data
# [0 3]
# array([[0.9507, 0.7683],
#        [0.3937, 0.6786],
#        [0.1226, 0.7137],
#        ...,
#        [0.3636, 0.5757],
#        [0.1307, 0.6026],
#        [0.9159, 0.5446]])

# %% [markdown]
# # Modified RNE version 1

# %%
def robust_neighbor_embedding_modified(X, n_neighbors, out_dim, tol=1e-6, max_iter=200):
    
    # LLE's weight matrix
    #W = weight_LLE(X, n_neighbors)
    se = SpectralEmbedding(n_components=2, affinity='nearest_neighbors', n_neighbors=se_nbrs)
    W = se.fit_transform(data)
#     se = SpectralEmbedding(n_components=X, affinity='nearest_neighbors', n_neighbors=se_nbrs)
#     W = se.fit_transform(X)
#     W
    
    #W = SpectralEmbedding(X, n_neighbors)
    n,d = X.shape
    H = np.random.rand(d,out_dim)
    ## W
    
    # M = (I-W)' (I-W)
    #A = eye(*W.shape, format=W.format) - W
    #A = (A.T).dot(A).tocsr()
    A = np.dot((np.eye(n) - np.transpose(W[:,None])), X)  
    A = A[1,:,:].reshape(n,d)
    AA = np.dot(np.transpose(A),A) #.tocsr()
    AAplus = 0.5 * (np.abs(AA) + AA)
    AAsubtract = 0.5 * (np.abs(AA) - AA)
    
    #initialize H, Y, alpha, gamma, gamma_max, mu
    M = np.dot(A, H)
    Y = np.zeros((n,out_dim))
    mu = 1.1
    gamma = 10
    max_gamma = 10000000000.0
    alpha = 1000.0
    iter_num = 100
    iter_numH = 100

    eps = 0.0001

    for j in np.arange(1, iter_num+1):
        AM = np.dot(np.transpose(A), M)
        AY = np.dot(np.transpose(A), Y)
        AMplus = 0.5 * (np.abs(AM) + AM)
        AMsubtract = 0.5 * (np.abs(AM) - AM)
        AYplus = 0.5 * (np.abs(AY) + AY)
        AYsubtract = 0.5 * (np.abs(AY) - AY)

        #update H
        for i in np.arange(1, iter_numH+1):

            G1 = np.diag(np.sqrt(1.0 / np.diag(np.dot(np.transpose(H), H)) + eps))
            #print("G1", G1)
            H = np.dot(H, G1)
            a = (np.dot((alpha * H ), np.dot(np.transpose(H), H))+gamma * AMsubtract + gamma * np.dot(AAplus,H)+ AYsubtract + eps)
            c = ((alpha * H) + (gamma * AMplus) + np.dot(gamma*AAsubtract, H) + AYplus)
            H = H * np.sqrt(c/a)        
        
        # Update M
        temp = np.dot(A,H)-Y/gamma
        M = pywt.threshold(temp,1/gamma, mode='soft')

        # Update Y
        Y = Y + gamma*(M-np.dot(A,H))
        
        # Update gamma
        gamma = min(mu*gamma,max_gamma)

    index_amplitude = np.sum(H*H,axis=1) #contribution of each feature 1~d
    ranking = np.argsort(-index_amplitude) #biggest first
    selected_index = ranking[0:out_dim] #select 1~out_dim

    X_rne = X[:,selected_index]
    print(selected_index)

    return X_rne #,selected_index, H

# %% [markdown]
# # Modified RNE version 2

# %%
def robust_neighbor_embedding_modified_2(X, n_neighbors, out_dim, tol=1e-6, max_iter=200):


    X = data
    n_neighbors = 45
    out_dim = 2 
    tol=1e-6
    max_iter=200
    
    # LLE's weight matrix
    W = weight_LLE(X, n_neighbors)
    #se = SpectralEmbedding(n_components=2, affinity='nearest_neighbors', n_neighbors=se_nbrs)
    #W = se.fit_transform(data)
#     se = SpectralEmbedding(n_components=X, affinity='nearest_neighbors', n_neighbors=se_nbrs)
#     W = se.fit_transform(X)
#     W
    
    #W = SpectralEmbedding(X, n_neighbors)
    n,d = X.shape
    H = np.random.rand(d,out_dim)
    ## W
    allH = []
    
    # M = (I-W)' (I-W)
    #A = eye(*W.shape, format=W.format) - W
    #A = (A.T).dot(A).tocsr()
    A = np.dot((np.eye(n) - np.transpose(W)), X)  
    AA = np.dot(np.transpose(A),A) #.tocsr()
    AAplus = 0.5 * (np.abs(AA) + AA)
    AAsubtract = 0.5 * (np.abs(AA) - AA)
    
    #initialize H, Y, alpha, gamma, gamma_max, mu
    M = np.dot(A, H)
    Y = np.zeros((n,out_dim))
    mu = 1.1
    gamma = 10
    max_gamma = 10000000000.0
    alpha = 1000.0
    iter_num = 50
    iter_numH = 30

    eps = 0.0001

    for j in np.arange(1, iter_num+1):
        AM = np.dot(np.transpose(A), M)
        AY = np.dot(np.transpose(A), Y)
        AMplus = 0.5 * (np.abs(AM) + AM)
        AMsubtract = 0.5 * (np.abs(AM) - AM)
        AYplus = 0.5 * (np.abs(AY) + AY)
        AYsubtract = 0.5 * (np.abs(AY) - AY)

        #update H
        for i in np.arange(1, iter_numH+1):

            G1 = np.diag(np.sqrt(1.0 / np.diag(np.dot(np.transpose(H), H)) + eps))
            #print("G1", G1)
            H = np.dot(H, G1)
            a = (np.dot((alpha * H ), np.dot(np.transpose(H), H))+gamma * AMsubtract + gamma * np.dot(AAplus,H)+ AYsubtract + eps)
            c = ((alpha * H) + (gamma * AMplus) + np.dot(gamma*AAsubtract, H) + AYplus)
            H = H * np.sqrt(c/a)  
            allH.append(H)
            newH = np.concatenate(allH)
            newH_fea = newH[0:len(X),]
        
        # Update M
        temp = np.dot(A,H)-Y/gamma
        M = pywt.threshold(temp,1/gamma, mode='soft')

        # Update Y
        Y = Y + gamma*(M-np.dot(A,H))
        
        # Update gamma
        gamma = min(mu*gamma,max_gamma)

    index_amplitude = np.sum(newH_fea*newH_fea,axis=1) #contribution of each feature 1~d
    ranking = np.argsort(-index_amplitude) #biggest first
    selected_index = ranking[0:out_dim] #select 1~out_dim
    print(selected_index)
#X_rne = X[:,selected_index]
    return newH_fea.round(4)


#,selected_index, H

# %% [markdown]
# # Original data

# %%
colors = ['red','lime','blue','black']

fig = plt.figure()
ax1 = fig.add_subplot(1,2,1, projection='3d')
ax1.scatter3D(data[:,0], data[:,1], data[:,2], c = label, 
              cmap = matplotlib.colors.ListedColormap(colors), s = 4);
ax2 = fig.add_subplot(1,2,2)
ax2.scatter(data_2d[:,0], data_2d[:,1],c = label, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
fig.set_size_inches(14,6)
plt.show()
# Out:
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# # Embedded LLE and Spectral with neighbors = 45

# %%
lle_nbrs = 45
lle = LocallyLinearEmbedding(n_components=2, n_neighbors=lle_nbrs)
data_on_lle = lle.fit_transform(data)

se_nbrs = 45
se = SpectralEmbedding(n_components=2, affinity='nearest_neighbors', n_neighbors=se_nbrs)
data_on_se = se.fit_transform(data)


fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.scatter(data_on_lle[:,0], data_on_lle[:,1],c = label, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax1.set_title('LLE; n_neighbors='+str(lle_nbrs))


ax2 = fig.add_subplot(1,2,2)
ax2.scatter(data_on_se[:,0], data_on_se[:,1],c = label, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax2.set_title('Spectral Embedding; n_neighbors='+str(se_nbrs))

fig.set_size_inches(14,6)
plt.show()
# Out:
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
rne_nbrs1 = 45
rne1 = robust_neighbor_embedding_modified(data, n_neighbors=rne_nbrs1, out_dim=2, tol=1e-6, max_iter=200)
data_on_rne1 = rne1

rne_nbrs2 = 45
rne2 = robust_neighbor_embedding_modified_2(data_2d, n_neighbors=rne_nbrs2, out_dim=2, tol=1e-6, max_iter=200)
data_on_rne2 = rne2

fig = plt.figure()


ax1 = fig.add_subplot(1,2,1)
ax1.scatter(data_on_rne1[:,0], data_on_rne1[:,1],c = label, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax1.set_title('Modified RNE with Spectral; n_neighbors='+str(rne_nbrs1))


ax2 = fig.add_subplot(1,2,2)
ax2.scatter(data_on_rne2[:,0], data_on_rne2[:,1],c = label, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax2.set_title('Modified RNE by Clustering with matrix H; n_neighbors='+str(rne_nbrs2))

fig.set_size_inches(20,12)

plt.show()
# Out:
# finding  45  neighbors for  1600  data
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
colors = ['red','lime','blue','black']

fig = plt.figure()

ax2 = fig.add_subplot(1,2,2)
ax2.scatter(data_2d[:,0], data_2d[:,1],c = label, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )

ax2.set_title('Original dataset; n_neighbors='+str(rne_nbrs))
fig.set_size_inches(20,12)
plt.show()

rne_nbrs = 45
rne = robust_neighbor_embedding(data, n_neighbors=rne_nbrs, out_dim=2, tol=1e-6, max_iter=200)
data_on_rne = rne

ax0 = fig.add_subplot(1,2,1)
ax0.scatter(data_on_rne[:,0], data_on_rne[:,1],c = label, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax0.set_title('Original RNE; n_neighbors='+str(rne_nbrs))


fig.set_size_inches(20,12)

plt.show()
# Out:
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()
# finding  45  neighbors for  1600  data
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
kmc_lle = KMeans(n_clusters=4, n_init=100, max_iter=300, tol=0.0001)
lle_clusters = kmc_lle.fit_predict(data_on_lle)

fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.scatter(data_on_lle[:,0], data_on_lle[:,1],c = lle_clusters, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax1.set_title('K-means on LLE domain')

ax2 = fig.add_subplot(1,2,2)
ax2.scatter(data_2d[:,0], data_2d[:,1],c = lle_clusters, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax2.set_title('Clustering results on original 2D domain')

fig.set_size_inches(14,6)
plt.show()

# %%
kmc_se = KMeans(n_clusters=4, n_init=100, max_iter=300, tol=0.0001)
se_clusters = kmc_se.fit_predict(data_on_se)

colors2 = ['blue','lime','black','red']

fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.scatter(data_on_se[:,0], data_on_se[:,1],c = se_clusters, 
            cmap = matplotlib.colors.ListedColormap(colors2), s = 4 )
ax1.set_title('K-means on SE domain')
ax2 = fig.add_subplot(1,2,2)
ax2.scatter(data_2d[:,0], data_2d[:,1],c = se_clusters, 
            cmap = matplotlib.colors.ListedColormap(colors2), s = 4 )
ax2.set_title('Clustering results on original 2D domain')

fig.set_size_inches(14,6)
plt.show()

# %%
kmc_rne = KMeans(n_clusters=4, n_init=100, max_iter=300, tol=0.0001)
rne_clusters = kmc_rne.fit_predict(data_on_rne)

fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.scatter(data_on_rne[:,0], data_on_rne[:,1],c = rne_clusters, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax1.set_title('K-means on original RNE domain')

ax2 = fig.add_subplot(1,2,2)
ax2.scatter(data_2d[:,0], data_2d[:,1],c = rne_clusters, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax2.set_title('Clustering results on original 2D domain')

fig.set_size_inches(14,6)
plt.show()

# %%
kmc_rne1 = KMeans(n_clusters=4, n_init=100, max_iter=300, tol=0.0001)
rne_clusters1 = kmc_rne1.fit_predict(data_on_rne1)

fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.scatter(data_on_rne1[:,0], data_on_rne1[:,1],c = rne_clusters1, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax1.set_title('K-means on modified RNE domain 1')

ax2 = fig.add_subplot(1,2,2)
ax2.scatter(data_2d[:,0], data_2d[:,1],c = rne_clusters1, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax2.set_title('Clustering results on original 2D domain')

fig.set_size_inches(14,6)
plt.show()

# %%
kmc_rne2 = KMeans(n_clusters=4, n_init=100, max_iter=300, tol=0.0001)
rne_clusters2 = kmc_rne.fit_predict(data_on_rne2)

fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.scatter(data_on_rne2[:,0], data_on_rne2[:,1],c = rne_clusters2, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax1.set_title('K-means on original RNE domain')

ax2 = fig.add_subplot(1,2,2)
ax2.scatter(data_2d[:,0], data_2d[:,1],c = rne_clusters2, 
            cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
ax2.set_title('Clustering results on original 2D domain')

fig.set_size_inches(14,6)
plt.show()

# %%
#for testing n_neighbors for LLE and Spectral Embedding

from sklearn.manifold import LocallyLinearEmbedding, SpectralEmbedding

matplotlib.use('Agg')
'''
for i in range(1,101):
    lle_nbrs =  i*5
    lle = LocallyLinearEmbedding(n_components=2, n_neighbors=lle_nbrs)
    data_on_lle = lle.fit_transform(data)

    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.scatter(data_on_lle[:,0], data_on_lle[:,1],c = label, 
               cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
    ax.set_title('LLE; n_neighbors='+str(lle_nbrs))
    filename = 'Figure'+'{0:04}'.format(lle_nbrs)+'.png'
    plt.savefig(filename)
plt.close('all')
'''
for i in range(1,31):

    rne_nbrs = i*5
    rne = robust_neighbor_embedding(data, n_neighbors=rne_nbrs, out_dim=2, tol=1e-6, max_iter=200)
    #se = SpectralEmbedding(n_components=2, affinity='rbf', n_neighbors=se_nbrs)
    #data_on_se = se.fit_transform(data)

    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.scatter(rne[:,0], rne[:,1],c = label, 
               cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
    ax.set_title('Original RNE; n_neighbors='+str(rne_nbrs))
    filename = 'Original RNE'+'{0:04}'.format(rne_nbrs)+'.png'
    plt.savefig(filename)
    
plt.close('all')
# Out:
# finding  5  neighbors for  1600  data
# finding  10  neighbors for  1600  data
# finding  15  neighbors for  1600  data
# finding  20  neighbors for  1600  data
# finding  25  neighbors for  1600  data
# finding  30  neighbors for  1600  data
# finding  35  neighbors for  1600  data
# finding  40  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  50  neighbors for  1600  data
# finding  55  neighbors for  1600  data
# finding  60  neighbors for  1600  data
# finding  65  neighbors for  1600  data
# finding  70  neighbors for  1600  data
# finding  75  neighbors for  1600  data
# finding  80  neighbors for  1600  data
# finding  85  neighbors for  1600  data
# finding  90  neighbors for  1600  data
# finding  95  neighbors for  1600  data
# finding  100  neighbors for  1600  data
# finding  105  neighbors for  1600  data
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# finding  110  neighbors for  1600  data
# finding  115  neighbors for  1600  data
# finding  120  neighbors for  1600  data
# finding  125  neighbors for  1600  data
# finding  130  neighbors for  1600  data
# finding  135  neighbors for  1600  data
# finding  140  neighbors for  1600  data
# finding  145  neighbors for  1600  data
# finding  150  neighbors for  1600  data

# %%
#for testing n_neighbors for LLE and Spectral Embedding

from sklearn.manifold import LocallyLinearEmbedding, SpectralEmbedding

matplotlib.use('Agg')
'''
for i in range(1,101):
    lle_nbrs =  i*5
    lle = LocallyLinearEmbedding(n_components=2, n_neighbors=lle_nbrs)
    data_on_lle = lle.fit_transform(data)

    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.scatter(data_on_lle[:,0], data_on_lle[:,1],c = label, 
               cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
    ax.set_title('LLE; n_neighbors='+str(lle_nbrs))
    filename = 'Figure'+'{0:04}'.format(lle_nbrs)+'.png'
    plt.savefig(filename)
plt.close('all')
'''
for i in range(5,31):

    rne_nbrs = i*10
    rne = robust_neighbor_embedding_modified(data, n_neighbors=rne_nbrs, out_dim=2, tol=1e-6, max_iter=200)
    #se = SpectralEmbedding(n_components=2, affinity='rbf', n_neighbors=se_nbrs)
    #data_on_se = se.fit_transform(data)

    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.scatter(rne[:,0], rne[:,1],c = label, 
               cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
    ax.set_title('modified RNE 1; n_neighbors='+str(rne_nbrs))
    filename = 'modified RNE 1'+'{0:04}'.format(rne_nbrs)+'.png'
    plt.savefig(filename)
    
plt.close('all')
# Out:
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
#for testing n_neighbors for LLE and Spectral Embedding

from sklearn.manifold import LocallyLinearEmbedding, SpectralEmbedding

matplotlib.use('Agg')
'''
for i in range(1,101):
    lle_nbrs =  i*5
    lle = LocallyLinearEmbedding(n_components=2, n_neighbors=lle_nbrs)
    data_on_lle = lle.fit_transform(data)

    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.scatter(data_on_lle[:,0], data_on_lle[:,1],c = label, 
               cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
    ax.set_title('LLE; n_neighbors='+str(lle_nbrs))
    filename = 'Figure'+'{0:04}'.format(lle_nbrs)+'.png'
    plt.savefig(filename)
plt.close('all')
'''
for i in range(1,15):

    rne_nbrs2 = i*5
    rne2 = robust_neighbor_embedding_modified_2(data, n_neighbors=rne_nbrs2, out_dim=2, tol=1e-6, max_iter=200)
    #se = SpectralEmbedding(n_components=2, affinity='rbf', n_neighbors=se_nbrs)
    #data_on_se = se.fit_transform(data)

    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.scatter(rne2[:,0], rne2[:,1],c = label, 
               cmap = matplotlib.colors.ListedColormap(colors), s = 4 )
    ax.set_title('modified RNE 2; n_neighbors='+str(rne_nbrs2))
    filename = 'modified RNE 2'+'{0:04}'.format(rne_nbrs2)+'.png'
    plt.savefig(filename)
    
plt.close('all')
# Out:
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-b15c2d3336ff> in <module>
#      22
#      23     rne_nbrs2 = i*5
# ---> 24     rne2 = robust_neighbor_embedding_modified_2(data, n_neighbors=rne_nbrs2, out_dim=2, tol=1e-6, max_iter=200)
#      25     #se = SpectralEmbedding(n_components=2, affinity='rbf', n_neighbors=se_nbrs)
#      26     #data_on_se = se.fit_transform(data)
#
# <ipython-input-53-16a29ce2cb81> in robust_neighbor_embedding_modified_2(X, n_neighbors, out_dim, tol, max_iter)
#       9
#      10     # LLE's weight matrix
# ---> 11     W = weight_LLE(X, n_neighbors)
#      12     #se = SpectralEmbedding(n_components=2, affinity='nearest_neighbors', n_neighbors=se_nbrs)
#      13     #W = se.fit_transform(data)
#
# <ipython-input-50-46086d7ff5f3> in weight_LLE(data, n_neighbors)
#      22     # Compute the nearest neighbors
#      23     print("finding ",n_neighbors," neighbors for ",n," data")
# ---> 24     neighbors_idx = find_neighbors(data, n_neighbors)
#      25
#      26     w = np.zeros((n, n))
#
# <ipython-input-50-46086d7ff5f3> in find_neighbors(X, n_neighbors)
#      10
#      11     # Compute full distance matrix (n , n)
# ---> 12     distances = np.array([[dist(p1, p2) for p2 in X] for p1 in X])
#      13
#      14     # by default, Keep only the 6 nearest neighbors, others set to 0 (= unreachable)
#
# <ipython-input-50-46086d7ff5f3> in <listcomp>(.0)
#      10
#      11     # Compute full distance matrix (n , n)
# ---> 12     distances = np.array([[dist(p1, p2) for p2 in X] for p1 in X])
#      13
#      14     # by default, Keep only the 6 nearest neighbors, others set to 0 (= unreachable)
#
# <ipython-input-50-46086d7ff5f3> in <listcomp>(.0)
#      10
#      11     # Compute full distance matrix (n , n)
# ---> 12     distances = np.array([[dist(p1, p2) for p2 in X] for p1 in X])
#      13
#      14     # by default, Keep only the 6 nearest neighbors, others set to 0 (= unreachable)
#
# <ipython-input-50-46086d7ff5f3> in dist(a, b)
#       7     """
#       8     def dist(a, b):
# ----> 9         return np.sqrt(sum((a - b)**2))
#      10
#      11     # Compute full distance matrix (n , n)
#
# KeyboardInterrupt:

# %%
rne4 = robust_neighbor_embedding(data, 4, 2, tol=1e-6, max_iter=200)
rne6 = robust_neighbor_embedding(data, 6, 2, tol=1e-6, max_iter=200)
rne8 = robust_neighbor_embedding(data, 8, 2, tol=1e-6, max_iter=200)
rne10 = robust_neighbor_embedding(data, 10, 2, tol=1e-6, max_iter=200)
rne12 = robust_neighbor_embedding(data, 12, 2, tol=1e-6, max_iter=200)
rne14 = robust_neighbor_embedding(data, 14, 2, tol=1e-6, max_iter=200)
rne16 = robust_neighbor_embedding(data, 16, 2, tol=1e-6, max_iter=200)
rne18 = robust_neighbor_embedding(data, 18, 2, tol=1e-6, max_iter=200)
# Out:
# finding  4  neighbors for  1600  data
# [0 2]
# finding  6  neighbors for  1600  data
# [2 0]
# finding  8  neighbors for  1600  data
# [0 1]
# finding  10  neighbors for  1600  data
# [1 0]
# finding  12  neighbors for  1600  data
# [0 1]
# finding  14  neighbors for  1600  data
# [0 2]
# finding  16  neighbors for  1600  data
# [0 1]
# finding  18  neighbors for  1600  data
# [2 1]

# %%
plt.figure(figsize=(12,14))

plt.subplot(4,2,1)
plt.title('4 neighborhoods')
plt.scatter(rne4[:, 0], rne4[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,2)
plt.title('6 neighborhoods')
plt.scatter(rne6[:, 0], rne6[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,3)
plt.title('8 neighborhoods')
plt.scatter(rne8[:, 0], rne8[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,4)
plt.title('10 neighborhoods')
plt.scatter(rne10[:, 0], rne10[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,5)
plt.title('12 neighborhoods')
plt.scatter(rne12[:, 0], rne12[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,6)
plt.title('14 neighborhoods')
plt.scatter(rne14[:, 0], rne14[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,7)
plt.title('16 neighborhoods')
plt.scatter(rne16[:, 0], rne16[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,8)
plt.title('18 neighborhoods')
plt.scatter(rne18[:, 0], rne18[:, 1], c=label)
plt.grid(True)

plt.show()
# Out:
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:43: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
mrne4 = robust_neighbor_embedding_modified(data, 4, 2, tol=1e-6, max_iter=200)
mrne6 = robust_neighbor_embedding_modified(data, 6, 2, tol=1e-6, max_iter=200)
mrne8 = robust_neighbor_embedding_modified(data, 8, 2, tol=1e-6, max_iter=200)
mrne10 = robust_neighbor_embedding_modified(data, 10, 2, tol=1e-6, max_iter=200)
mrne12 = robust_neighbor_embedding_modified(data, 12, 2, tol=1e-6, max_iter=200)
mrne14 = robust_neighbor_embedding_modified(data, 14, 2, tol=1e-6, max_iter=200)
mrne16 = robust_neighbor_embedding_modified(data, 16, 2, tol=1e-6, max_iter=200)
mrne18 = robust_neighbor_embedding_modified(data, 18, 2, tol=1e-6, max_iter=200)

# %%
plt.figure(figsize=(12,14))

plt.subplot(4,2,1)
plt.title('4 neighborhoods')
plt.scatter(mrne4[:, 0], mrne4[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,2)
plt.title('6 neighborhoods')
plt.scatter(mrne6[:, 0], mrne6[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,3)
plt.title('8 neighborhoods')
plt.scatter(mrne8[:, 0], mrne8[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,4)
plt.title('10 neighborhoods')
plt.scatter(mrne10[:, 0], mrne10[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,5)
plt.title('12 neighborhoods')
plt.scatter(mrne12[:, 0], mrne12[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,6)
plt.title('14 neighborhoods')
plt.scatter(mrne14[:, 0], mrne14[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,7)
plt.title('16 neighborhoods')
plt.scatter(mrne16[:, 0], mrne16[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,8)
plt.title('18 neighborhoods')
plt.scatter(mrne18[:, 0], mrne18[:, 1], c=label)
plt.grid(True)

plt.show()
# Out:
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:43: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
m2rne4 = robust_neighbor_embedding_modified_2(data, 4, 2, tol=1e-6, max_iter=200)
m2rne6 = robust_neighbor_embedding_modified_2(data, 6, 2, tol=1e-6, max_iter=200)
m2rne8 = robust_neighbor_embedding_modified_2(data, 8, 2, tol=1e-6, max_iter=200)
m2rne10 = robust_neighbor_embedding_modified_2(data, 10, 2, tol=1e-6, max_iter=200)
m2rne12 = robust_neighbor_embedding_modified_2(data, 12, 2, tol=1e-6, max_iter=200)
m2rne14 = robust_neighbor_embedding_modified_2(data, 14, 2, tol=1e-6, max_iter=200)
m2rne16 = robust_neighbor_embedding_modified_2(data, 16, 2, tol=1e-6, max_iter=200)
m2rne18 = robust_neighbor_embedding_modified_2(data, 18, 2, tol=1e-6, max_iter=200)
# Out:
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data
# finding  45  neighbors for  1600  data

# %%
plt.figure(figsize=(12,14))

plt.subplot(4,2,1)
plt.title('4 neighborhoods')
plt.scatter(m2rne4[:, 0], m2rne4[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,2)
plt.title('6 neighborhoods')
plt.scatter(m2rne6[:, 0], m2rne6[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,3)
plt.title('8 neighborhoods')
plt.scatter(m2rne8[:, 0], m2rne8[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,4)
plt.title('10 neighborhoods')
plt.scatter(m2rne10[:, 0], m2rne10[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,5)
plt.title('12 neighborhoods')
plt.scatter(m2rne12[:, 0], m2rne12[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,6)
plt.title('14 neighborhoods')
plt.scatter(m2rne14[:, 0], m2rne14[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,7)
plt.title('16 neighborhoods')
plt.scatter(m2rne16[:, 0], m2rne16[:, 1], c=label)
plt.grid(True)

plt.subplot(4,2,8)
plt.title('18 neighborhoods')
plt.scatter(m2rne18[:, 0], m2rne18[:, 1], c=label)
plt.grid(True)

plt.show()
# Out:
# /Users/jarinyalimpanadusadee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:43: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
